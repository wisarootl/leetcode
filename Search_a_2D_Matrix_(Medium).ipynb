# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Search_a_2D_Matrix_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Search a 2D Matrix II

# %% [markdown]
# Write an efficient algorithm that searches for a value target in an m x n integer matrix matrix. This matrix has the following properties:
#
# - Integers in each row are sorted from left to right.
# - The first integer of each row is greater than the last integer of the previous row.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 1:
#
# ```
# Input: matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]], target = 3
# Output: true
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 2:
#
# ```
# Input: matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]], target = 13
# Output: false
# ```

# %% [markdown]
# Constraints:
#
# ```
# m == matrix.length
# n == matrix[i].length
# 1 <= m, n <= 100
# -104 <= matrix[i][j], target <= 104
# ```

# %%
class Solution:
    def searchMatrix(self, matrix, target):
        m = len(matrix)
        n = len(matrix[0])
        left_idx = 0
        right_idx = m * n - 1
        
        while left_idx <= right_idx:
            mid_idx = (left_idx + right_idx) // 2
            mid_row = mid_idx // n
            mid_col = mid_idx % n
            
            if target == matrix[mid_row][mid_col]:
                return True
            elif target < matrix[mid_row][mid_col]:
                right_idx= mid_idx - 1
            else:
                left_idx = mid_idx + 1
        
        return False

# %%
matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]
target = 3
expected = True

output = Solution().searchMatrix(matrix, target)
print(output)
assert output == expected
# Out:
# True

# %%
matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]
target = 13
expected = False

output = Solution().searchMatrix(matrix, target)
print(output)
assert output == expected
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)
