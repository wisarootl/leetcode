# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Powerset_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Powerset

# %% [markdown]
# Write a function that takes in an array of unique integers and returns its powerset.
#
# The powerset `P(X)` of a set `X` is the set of all subsets of `X`. For example, the powerset of `[1,2]` is `[[], [1], [2], [1,2]]`.
#
# Note that the sets in the powerset do not need to be in any particular order.

# %% [markdown]
# Sample Input
#
# ```
# array = [1, 2, 3]
# ```

# %% [markdown]
# Sample Output
#
# ```
# [[], [1], [2], [3], [1, 2], [1, 3], [2, 3], [1, 2, 3]]
# ```

# %% [markdown]
# # Solution 1 : iterative

# %%
# Time O(n*2^n)
# Space O(n*2^n)

def powerset(array):
	subset = [[]]
	for element in array:
		for i in range(len(subset)):
			current_subset = subset[i] + [element]
			subset.append(current_subset)
	return subset

# %%
array = [1, 2, 3]
powerset(array)
# Out:
# [[], [1], [2], [1, 2], [3], [1, 3], [2, 3], [1, 2, 3]]

# %% [markdown]
# ![photo_2022-01-13_09-47-48.jpg](data:image/jpeg;base64,...)

# %%
def powerset(array, idx=None):
    if idx is None:
        idx = len(array) - 1
    if idx < 0:
        return [[]]
    ele = array[idx]
    subsets = powerset(array, idx - 1)
    for i in range(len(subsets)):
        currentSubset = subsets[i]
        subsets.append(currentSubset + [ele])
    return subsets

# %%
array = [1, 2, 3]
powerset(array)
# Out:
# [[], [1], [2], [1, 2], [3], [1, 3], [2, 3], [1, 2, 3]]

# %%
array = []
powerset(array)
# Out:
# [[]]

# %% [markdown]
# # Solution 2 : Recursive

# %%
# Time O(n*2^n)
# Space O(n*2^n)

def powerset(array, idx = None):
  # [1, 2, 3, 4]
  if idx == None:
    idx = len(array) - 1
  if idx < 0:
    return [[]]
  # ele = 4
  ele = array[idx]
  # subset = powerset([1, 2, 3])
  subsets = powerset(array, idx - 1)
  for i in range(len(subsets)):
    current_subset = subsets[i]
    subsets.append(current_subset + [ele])
  return subsets

# %%
array = [1, 2, 3]
powerset(array)
# Out:
# [[], [1], [2], [1, 2], [3], [1, 3], [2, 3], [1, 2, 3]]

# %%
array = []
powerset(array)
# Out:
# [[]]
