# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Score_of_Parentheses_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Score of Parentheses

# %% [markdown]
# Given a balanced parentheses string s, return the score of the string.
#
# The score of a balanced parentheses string is based on the following rule:
#
# "()" has score 1.
# AB has score A + B, where A and B are balanced parentheses strings.
# (A) has score 2 * A, where A is a balanced parentheses string.

# %% [markdown]
# Example 1:
#
# ```
# Input: s = "()"
# Output: 1
# ```

# %% [markdown]
# Example 2:
#
# ```
# Input: s = "(())"
# Output: 2
# ```

# %% [markdown]
# Example 3:
#
# ```
# Input: s = "()()"
# Output: 2
# ```

# %% [markdown]
# Constraints:
#
# ```
# 2 <= s.length <= 50
# s consists of only '(' and ')'.
# s is a balanced parentheses string.
# ```

# %% [markdown]
# # Solution 1 : Stack

# %%
# Time = O(n)
# Space = O(n)

class Solution:
    def scoreOfParentheses(self, s):
      stack = [0]

      for char in s:
        if char == '(':
          stack.append(0)
        elif char == ')':
          temp = stack.pop()
          stack[-1] += max(2 * temp, 1)
      
      return stack.pop()

# %%
s = '(()(()))'
expected = 6

output = Solution().scoreOfParentheses(s)
print(output)
assert output == expected
# Out:
# 6

# %% [markdown]
# # Solution 2 : Count Open Parentheses

# %%
# Time = O(n)
# Space = O(1)

class Solution:
    def scoreOfParentheses(self, s):
      score = 0
      open_parentheses_count = 0
      for idx, char in enumerate(s):
        if char == '(':
          open_parentheses_count += 1
        else:
          open_parentheses_count -= 1
          if s[idx - 1] == '(':
            score += 2**(open_parentheses_count)
      
      return score

# %%
s = '(()(()))'
expected = 6

output = Solution().scoreOfParentheses(s)
print(output)
assert output == expected
# Out:
# 6

# %% [markdown]
# ![photo_2022-03-17_08-55-06.jpg](data:image/jpeg;base64,...)
