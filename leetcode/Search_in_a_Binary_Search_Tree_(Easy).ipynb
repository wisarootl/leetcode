# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Search_in_a_Binary_Search_Tree_(Easy).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Search in a Binary Search Tree

# %% [markdown]
# You are given the root of a binary search tree (BST) and an integer val.
#
# Find the node in the BST that the node's value equals val and return the subtree rooted with that node. If such a node does not exist, return null.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 1:
#
# ```
# Input: root = [4,2,7,1,3], val = 2
# Output: [2,1,3]
# ```

# %% [markdown]
# Example 2:
#
# ```
# Input: root = [4,2,7,1,3], val = 5
# Output: []
# ```

# %% [markdown]
# # Solution 1 : Recursion

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# Time = O(log n) for avg case and O(n) for worst case
# Sapce = O(log n) for avg case and O(n) for worst case

class Solution:
    def searchBST(self, root, val):
        if root == None:
            return
        elif root.val == val:
            return root
        elif root.val > val:
            return self.searchBST(root.left, val)
        elif root.val < val:
            return self.searchBST(root.right, val)

# %%
tree = TreeNode(4)
tree.left = TreeNode(2)
tree.right = TreeNode(7)
tree.left.left = TreeNode(1)
tree.left.right  = TreeNode(3)

root = tree
val = 2
expected = tree.left

output = Solution().searchBST(root, val)
print(output.val if output else output)
assert output == expected
# Out:
# 2

# %%
tree = TreeNode(4)
tree.left = TreeNode(2)
tree.right = TreeNode(7)
tree.left.left = TreeNode(1)
tree.left.right  = TreeNode(3)

root = tree
val = 5
expected = None

output = Solution().searchBST(root, val)
print(output.val if output else output)
assert output == expected
# Out:
# None

# %% [markdown]
# # Solution 2 : Iteration

# %%
# Time = O(log n) for avg case and O(n) for worst case
# Sapce = O(1)

class Solution:
    def searchBST(self, root, val):
        while root is not None and root.val != val:
            root = root.left if val < root.val else root.right
        return root

# %%
tree = TreeNode(4)
tree.left = TreeNode(2)
tree.right = TreeNode(7)
tree.left.left = TreeNode(1)
tree.left.right  = TreeNode(3)

root = tree
val = 2
expected = tree.left

output = Solution().searchBST(root, val)
print(output.val if output else output)
assert output == expected
# Out:
# 2

# %%
tree = TreeNode(4)
tree.left = TreeNode(2)
tree.right = TreeNode(7)
tree.left.left = TreeNode(1)
tree.left.right  = TreeNode(3)

root = tree
val = 5
expected = None

output = Solution().searchBST(root, val)
print(output.val if output else output)
assert output == expected
# Out:
# None
