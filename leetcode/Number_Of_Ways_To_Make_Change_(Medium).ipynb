# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Number_Of_Ways_To_Make_Change_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Number Of Ways To Make Change

# %% [markdown]
# Given an array of distinct positive integers representing coin denominations and a single non-negative integer n representing a target amount of money, write a function that returns the number of ways to make change for that target amount using the given coin denominations.
#
# Note that an unlimited amount of coins is at your disposal.

# %% [markdown]
# Sample Input
#
# ```
# n = 6
# denoms = [1, 5]
# ```

# %% [markdown]
# Sample Output
#
# ```
# 2 // 1x1 + 1x5 and 6x1
# ```

# %%
# Time = O(d*n) : d = No. of types of coins, n = required change
# space = O(n) : we only store 1 row from conceptual note because we will look back at most 1 previous row 

def numberOfWaysToMakeChange(n, denoms):
	ways = [0] * (n + 1)
	ways[0] = 1

	for denom in denoms:
		for amount in range(1, len(ways)):
			if amount >= denom:
				ways[amount] += ways[amount-denom]

	return ways[-1]

# %%
n = 6
denoms = [1, 5]
print(numberOfWaysToMakeChange(n, denoms))
# Out:
# 2

# %% [markdown]
# ## Conceptual Note

# %% [markdown]
# ![photo_2021-11-23_07-40-40.jpg](data:image/jpeg;base64,...)
