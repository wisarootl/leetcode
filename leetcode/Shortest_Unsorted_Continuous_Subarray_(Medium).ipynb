# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Shortest_Unsorted_Continuous_Subarray_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Unsorted Continuous Subarray

# %% [markdown]
# Given an integer array nums, you need to find one continuous subarray that if you only sort this subarray in ascending order, then the whole array will be sorted in ascending order.
#
# Return the shortest such subarray and output its length.

# %% [markdown]
# Example 1:
#
# ```
#
# Input: nums = [2,6,4,8,10,9,15]
# Output: 5
# Explanation: You need to sort [6, 4, 8, 10, 9] in ascending order to make the whole array sorted in ascending order.
# ```

# %% [markdown]
# Example 2:
#
# ```
#
# Input: nums = [1,2,3,4]
# Output: 0
# ```

# %% [markdown]
# Example 3:
#
# ```
#
# Input: nums = [1]
# Output: 0
# ```

# %% [markdown]
# Constraints:
#
# ```
# 1 <= nums.length <= 104
# -105 <= nums[i] <= 105
# ```

# %%
class Solution:
    # Time = O(n)
    # Space = O(1)
    def findUnsortedSubarray(self, nums):
        length = len(nums)
        end = -1   
        start = 0
        maximum = nums[0]
        minimum = nums[length - 1]

        for i in range(1,length):
            if nums[i] >= maximum:
                maximum = nums[i]
            else:
                end = i

        for i in range(length-2,-1,-1):
            if nums[i] <= minimum:
                minimum = nums[i]
            else:
                start = i

        return end - start + 1

# %%
nums = [2,6,4,8,10,9,15]
expected = 5

output = Solution().findUnsortedSubarray(nums)
print(output)

assert output == expected
# Out:
# 5

# %%
nums = [1,2,3,4]
expected = 0

output = Solution().findUnsortedSubarray(nums)
print(output)

assert output == expected
# Out:
# 0

# %%
nums = [1]
expected = 0

output = Solution().findUnsortedSubarray(nums)
print(output)

assert output == expected
# Out:
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)
