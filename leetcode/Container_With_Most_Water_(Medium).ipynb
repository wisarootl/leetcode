# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Container_With_Most_Water_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Container With Most Water

# %% [markdown]
# You are given an integer array height of length n. There are n vertical lines drawn such that the two endpoints of the ith line are (i, 0) and (i, height[i]).
#
# Find two lines that together with the x-axis form a container, such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# Notice that you may not slant the container.

# %% [markdown]
# Example 1:
#
# ```
# Input: height = [1,8,6,2,5,4,8,3,7]
# Output: 49
# Explanation: The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 2:
#
# ```
# Input: height = [1,1]
# Output: 1
# ```

# %% [markdown]
# Constraints:
#
# ```
# n == height.length
# 2 <= n <= 105
# 0 <= height[i] <= 104
# ```

# %%
# Time = O(N)
# Space = O(1)

class Solution:
    def maxArea(self, height):
        left = 0
        right = len(height) - 1
        max_area = 0
        while left < right:
            area = min(height[left], height[right]) * (right - left)
            max_area = max(area, max_area)
            if height[left] <= height[right]:
                left += 1
            else: 
                right -= 1
        
        return max_area

# %%
height = [1,8,6,2,5,4,8,3,7]
expected = 49

output = Solution().maxArea(height)
print(output)
assert output == expected
# Out:
# 49

# %%
height = [1,1]
expected = 1

output = Solution().maxArea(height)
print(output)
assert output == expected
# Out:
# 1
