# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Strobogrammatic_Number_II_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strobogrammatic Number II

# %% [markdown]
# Given an integer n, return all the strobogrammatic numbers that are of length n. You may return the answer in any order.
#
# A strobogrammatic number is a number that looks the same when rotated 180 degrees (looked at upside down).

# %% [markdown]
# Example 1:
#
# ```
# Input: n = 2
# Output: ["11","69","88","96"]
# ```

# %% [markdown]
# Example 2:
#
# ```
# Input: n = 1
# Output: ["0","1","8"]
# ```

# %% [markdown]
# Constraints:
#
# ```
# 1 <= n <= 14
# ```

# %%
# Time = O(N^2 * 5^(N/2))
# Space = O(N * 5^(N/2))

class Solution:
    def findStrobogrammatic(self, n):
        valid_strobogrammatic_pair = [
            ['0', '0'], ['1', '1'], 
            ['6', '9'], ['8', '8'], ['9', '6']
        ]
        
        current_strings_length = n % 2
        
        if current_strings_length == 1:
            output = ['0', '1', '8']
        else:
            output = ['']
        
        while current_strings_length < n:
            current_strings_length += 2
            next_level = []
            
            for number in output:
                for pair in valid_strobogrammatic_pair:
                    if pair[0] != '0' or current_strings_length != n:
                        next_level.append(pair[0] + number + pair[1])
            output = next_level
            
        return output

# %%
print(Solution().findStrobogrammatic(0))
# Out:
# ['']

# %%
print(Solution().findStrobogrammatic(1))
# Out:
# ['0', '1', '8']

# %%
print(Solution().findStrobogrammatic(2))
# Out:
# ['11', '69', '88', '96']

# %%
print(Solution().findStrobogrammatic(3))
# Out:
# ['101', '609', '808', '906', '111', '619', '818', '916', '181', '689', '888', '986']

# %%
print(Solution().findStrobogrammatic(4))
# Out:
# ['1001', '6009', '8008', '9006', '1111', '6119', '8118', '9116', '1691', '6699', '8698', '9696', '1881', '6889', '8888', '9886', '1961', '6969', '8968', '9966']

# %% [markdown]
# # Conceptual Note

# %% [markdown]
# - Construct tree as in the picture below.
# - tree depth = N/2
# - tree width = 5^(N/2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
