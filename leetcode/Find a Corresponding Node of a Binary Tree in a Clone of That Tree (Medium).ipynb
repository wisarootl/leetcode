# %% [markdown]
# # Find a Corresponding Node of a Binary Tree in a Clone of That Tree

# %% [markdown]
# Given two binary trees original and cloned and given a reference to a node target in the original tree.
#
# The cloned tree is a copy of the original tree.
#
# Return a reference to the same node in the cloned tree.
#
# Note that you are not allowed to change any of the two trees or the target node and the answer must be a reference to a node in the cloned tree.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 1:
# ```
# Input: tree = [7,4,3,null,null,6,19], target = 3
# Output: 3
# Explanation: In all examples the original and cloned trees are shown. The target node is a green node from the original tree. The answer is the yellow node from the cloned tree.
# ```

# %% [markdown]
# Example 2:
# ```
# Input: tree = [7], target =  7
# Output: 7
# ```

# %% [markdown]
# Example 3:
# ```
# Input: tree = [8,null,6,null,5,null,4,null,3,null,2,null,1], target = 4
# Output: 4
# ```

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution:
    # Time = O(n)
    # Space = O(n)
    def getTargetCopy(self, original: TreeNode, cloned: TreeNode, target: TreeNode) -> TreeNode:
        stack_o, stack_c = [original], [cloned]
        
        while stack_o or node_c:
            node_o = stack_o.pop()
            node_c = stack_c.pop()
            
            if node_o is target:
                return node_c
            
            
            if node_o.right != None:
                stack_o.append(node_o.right)
            if node_o.left != None:
                stack_o.append(node_o.left)
                
            if node_c.right != None:
                stack_c.append(node_c.right)
            if node_c.left != None:
                stack_c.append(node_c.left)

# %%
original = TreeNode(7)
original.left = TreeNode(4)
original.right = TreeNode(3)
original.right.left = TreeNode(6)
original.right.right = TreeNode(19)

target = original.right

cloned = TreeNode(7)
cloned.left = TreeNode(4)
cloned.right = TreeNode(3)
cloned.right.left = TreeNode(6)
cloned.right.right = TreeNode(19)

expected = cloned.right

output = Solution().getTargetCopy(original, cloned, target)
print(output.val)
assert output == expected
# Out:
# 3
