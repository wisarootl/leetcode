# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Trim_a_Binary_Search_Tree_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trim a Binary Search Tree

# %% [markdown]
# Given the root of a binary search tree and the lowest and highest boundaries as low and high, trim the tree so that all its elements lies in [low, high]. Trimming the tree should not change the relative structure of the elements that will remain in the tree (i.e., any node's descendant should remain a descendant). It can be proven that there is a unique answer.
#
# Return the root of the trimmed binary search tree. Note that the root may change depending on the given bounds.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 1:
#
# ```
# Input: root = [1,0,2], low = 1, high = 2
# Output: [1,null,2]
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 2:
#
# ```
# Input: root = [3,0,4,null,2,null,null,1], low = 1, high = 3
# Output: [3,2,null,1]
# ```

# %% [markdown]
# Constraints:
#
# ```
# The number of nodes in the tree in the range [1, 104].
# 0 <= Node.val <= 104
# The value of each node in the tree is unique.
# root is guaranteed to be a valid binary search tree.
# 0 <= low <= high <= 104
# ```

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def trimBST(self, root, low, high):
        if not root:
            return None
        elif root.val > high:
            return self.trimBST(root.left, low, high)
        elif root.val < low:
            return self.trimBST(root.right, low, high)
        
        root.left = self.trimBST(root.left, low, high)
        root.right = self.trimBST(root.right, low, high)
        return root

# %%
root = TreeNode(1)
root.left = TreeNode(0)
root.right = TreeNode(2)

low = 1
high = 2

output = Solution().trimBST(root, low, high)
print(output.val)
print(output.left, output.right.val)
# Out:
# 1
# None 2

# %%
root = TreeNode(3)
root.left = TreeNode(0)
root.right = TreeNode(4)
root.left.right = TreeNode(2)
root.left.right.left = TreeNode(1)

low = 1
high = 3

output = Solution().trimBST(root, low, high)
print(output.val)
print(output.left.val, output.right)
print(output.left.left.val, output.left.right)
# Out:
# 3
# 2 None
# 1 None
