# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Find_the_Duplicate_Number_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find the Duplicate Number

# %% [markdown]
# Given an array of integers nums containing n + 1 integers where each integer is in the range [1, n] inclusive.
#
# There is only one repeated number in nums, return this repeated number.
#
# You must solve the problem without modifying the array nums and uses only constant extra space.

# %% [markdown]
# Example 1:
#
# ```
# Input: nums = [1,3,4,2,2]
# Output: 2
# ```

# %% [markdown]
# Example 2:
#
# ```
# Input: nums = [3,1,3,4,2]
# Output: 3
# ```

# %% [markdown]
# Constraints:
#
# ```
# 1 <= n <= 105
# nums.length == n + 1
# 1 <= nums[i] <= n
# All the integers in nums appear only once except for precisely one integer which appears two or more times.
# ```

# %% [markdown]
# Follow up:
#
# ```
# How can we prove that at least one duplicate number must exist in nums?
# Can you solve the problem in linear runtime complexity?
# ```

# %% [markdown]
# # Solution

# %% [markdown]
# - transform to linked list
# - Floyd's Tortoise and Hare (cycly detection)

# %%
# Time = O(n)
# Space = O(1)

class Solution:
    def findDuplicate(self, nums):
        # first part
        fast_pointer, slow_pointer = nums[0], nums[0]
        while True:
            fast_pointer = nums[nums[fast_pointer]]
            slow_pointer = nums[slow_pointer]
            if fast_pointer == slow_pointer:
                break
                
        slow_pointer = nums[0]
        while fast_pointer != slow_pointer:
            fast_pointer = nums[fast_pointer]
            slow_pointer = nums[slow_pointer]
        
        return fast_pointer

# %%
nums = [1,3,4,2,2]
expected = 2

output = Solution().findDuplicate(nums)
print(output)
assert output == expected
# Out:
# 2

# %%
nums = [3,1,3,4,2]
expected = 3

output = Solution().findDuplicate(nums)
print(output)
assert output == expected
# Out:
# 3

# %%
nums = [2, 2, 2, 2, 2, 2]
expected = 2

output = Solution().findDuplicate(nums)
print(output)
assert output == expected
# Out:
# 2

# %% [markdown]
# ![photo_2022-03-29_10-24-47.jpg](data:image/jpeg;base64,...)
