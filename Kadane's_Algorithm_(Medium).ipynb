# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Kadane's_Algorithm_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kadane's Algorithm

# %% [markdown]
# Write a function that takes in a non-empty array of integers and returns the maximum sum that can be obtained by summing up all of the integers in a non-empty subarray of the input array. A subarray must only contain adjacent numbers (numbers next to each other in the input array).

# %% [markdown]
# Sample Input
#
# ```
# array = [3, 5, -9, 1, 3, -2, 3, 4, 7, 2, -9, 6, 3, 1, -5, 4]
# ```

# %% [markdown]
# Sample Output
#
# ```
# 19 // [1, 3, -2, 3, 4, 7, 2, -9, 6, 3, 1]
# ```

# %%
# Time O(n)
# Space O(1)
def kadanesAlgorithm(array):
	max_end_here = 0
	max_sum = 0
	for i in range(len(array)):
		max_end_here = max(max_end_here, array[i])
		max_sum = max(max_sum, max_end_here)
	return max_sum

# %%
array = [3, 5, -9, 1, 3, -2, 3, 4, 7, 2, -9, 6, 3, 1, -5, 4]
kadanesAlgorithm(array)
# Out:
# 7

# %% [markdown]
# ![photo_2022-01-07_12-08-49.jpg](data:image/jpeg;base64,...)
