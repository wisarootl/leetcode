# %% [markdown]
# <a href="https://colab.research.google.com/github/wisarootl/leetcode/blob/main/Spiral_Matrix_II_(Medium).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spiral Matrix II

# %% [markdown]
# Given a positive integer n, generate an n x n matrix filled with elements from 1 to n2 in spiral order.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example 1:
#
# ```
# Input: n = 3
# Output: [[1,2,3],[8,9,4],[7,6,5]
# ```

# %% [markdown]
# Example 2:
#
# ```
# Input: n = 1
# Output: [[1]]
# ```

# %% [markdown]
# Constraints:
#
# ```
# 1 <= n <= 20
# ```

# %%
class Solution:
    def generateMatrix(self, n):
        counter = 1
        top, bottom = 0, n - 1
        left, right = 0, n - 1
        array = [[None for _ in range(n)] for _ in range(n)]
        while bottom >= top:
            for col in range(left, right + 1):
                array[top][col] = counter
                counter += 1
            
            for row in range(top + 1, bottom + 1):
                array[row][right] = counter
                counter += 1
            
            for col in range(right - 1, left - 1, -1):
                array[bottom][col] = counter
                counter += 1
            
            for row in range(bottom - 1, top, -1):
                array[row][left] = counter
                counter += 1
            
            top += 1
            bottom -= 1
            left += 1
            right -= 1
        
        return array

# %%
n = 3
expected = [[1,2,3],[8,9,4],[7,6,5]]

output = Solution().generateMatrix(n)
print(output)
assert output == expected
# Out:
# [[1, 2, 3], [8, 9, 4], [7, 6, 5]]

# %%
n = 1
expected = [[1]]

output = Solution().generateMatrix(n)
print(output)
assert output == expected
# Out:
# [[1]]
